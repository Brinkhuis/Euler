# %% [markdown]
# # Problem 6
# https://projecteuler.net/problem=6

# %%
print('Python v{}'.format(__import__('sys').version.split()[0]))
# Out:
# Python v3.14.3

# %% [markdown]
# ### Solution

# %%
def sum_square_difference(n): return sum(range(1, n+1))**2 - sum([i**2 for i in range(1, n+1)])

assert sum_square_difference(10) == 2640

# %%
# answer
sum_square_difference(100)
# Out:
# 25164150

# %%
# benchmark
# %timeit sum_square_difference(100)
# Out:
# 3.01 μs ± 7.77 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Save benchmark

# %%
bm = %timeit -o sum_square_difference(100)
import euler
euler.save_benchmark(6, bm)
# Out:
# 3.05 μs ± 41.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
