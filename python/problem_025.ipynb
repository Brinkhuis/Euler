# %% [markdown]
# # Problem 25
# https://projecteuler.net/problem=25

# %%
print('Python v{}'.format(__import__('sys').version.split()[0]))
# Out:
# Python v3.14.3

# %% [markdown]
# ### Solution

# %%
def fibonacci():
    a, b = 0, 1
    while True:
        yield a
        a, b = b, a + b

# %%
def nthdigitfib(n):
    fib = fibonacci()
    counter = 0
    while True:
        f = next(fib)
        l = len(str(f))
        if l == n:
            return counter
        counter += 1

# %%
# answer
nthdigitfib(1_000)
# Out:
# 4782

# %%
# benchmark
# %timeit nthdigitfib(1_000)
# Out:
# 17.7 ms ± 204 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Save benchmark

# %%
bm = %timeit -o nthdigitfib(1_000)
import euler
euler.save_benchmark(25, bm)
# Out:
# 17.5 ms ± 146 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
