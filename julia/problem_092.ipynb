# %% [markdown]
# # Problem 92
# https://projecteuler.net/problem=92

# %%
println("Julia v", VERSION)
# Out:
# Julia v1.12.5

# %%
using BenchmarkTools

# %% [markdown]
# ### Solution

# %%
function square_digit_chains(n::Int64)::Bool
    n == 1 && return false
    n == 89 && return true
    while n ∉ [1, 89]
        n = sum(n^2 for n ∈ digits(n))
        n == 1 && return false
        n == 89 && return true
    end
end
# Out:
# square_digit_chains (generic function with 1 method)

# %%
@btime sum(map(square_digit_chains, 1:10^7-1))
# Out:
#   2.232 s (139571347 allocations: 5.46 GiB)
# 8581146
